# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.read_csv('data/Denmark/Raw/P05_07_DK.csv')
data2 = pd.read_csv('data/Denmark/Raw/P07_11_DK.csv')
data3 = pd.read_csv('data/Denmark/Raw/P11_15_DK.csv')
data4 = pd.read_csv('data/Denmark/Raw/P15_19_DK.csv')

# %%
data4
# Out:
#         Unnamed: 0  typeid_x  afstemningid  aktørid  \
# 0            68807         1          2629      117
# 1            68808         1          2629       17
# 2            68809         1          2629      152
# 3            68810         1          2629       50
# 4            68811         1          2629     3082
# ...            ...       ...           ...      ...
# 208396      771137         1          7406    17629
# 208397      771138         1          7406    17963
# 208398      771139         1          7406    18265
# 208399      771140         1          7406    18291
# 208400      771141         1          7406    18415
#
#                                party                 dato
# 0       Uden for folketingsgrupperne  2015-07-03 11:00:00
# 1                  Socialdemokratiet  2015-07-03 11:00:00
# 2                  Socialdemokratiet  2015-07-03 11:00:00
# 3       Uden for folketingsgrupperne  2015-07-03 11:00:00
# ...
