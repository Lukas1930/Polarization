# %%
import pandas as pd

members_117 = pd.read_csv('data/USA/H117_members.csv')
votes_117 = pd.read_csv('data/USA/H117_votes.csv')
members_118 = pd.read_csv('data/USA/H118_members.csv')
votes_118 = pd.read_csv('data/USA/H118_votes.csv')

members_117['icpsr'] = members_117['icpsr'].astype('Int64')
votes_117['icpsr'] = votes_117['icpsr'].astype('Int64')
members_118['icpsr'] = members_118['icpsr'].astype('Int64')
votes_118['icpsr'] = votes_118['icpsr'].astype('Int64')

merged_117 = votes_117.merge(members_117, on='icpsr')
merged_118 = votes_118.merge(members_118, on='icpsr')
# Out:
#    congress_x chamber_x  rollnumber  icpsr  cast_code   prob  congress_y  \
# 0         117     House           1  14066          6  100.0         117
# 1         117     House           1  14854          6  100.0         117
# 2         117     House           1  14863          6   99.7         117
# 3         117     House           1  14873          1  100.0         117
# 4         117     House           1  15019          1   92.8         117
#
#   chamber_y  state_icpsr  district_code  ...    died  nominate_dim1  \
# 0     House           81              1  ...  2022.0          0.283
# 1     House           51              5  ...     NaN          0.333
# 2     House           12              4  ...     NaN          0.180
# 3     House           52              5  ...     NaN         -0.382
# 4     House           54              5  ...     NaN         -0.164
#
#    nominate_dim2  nominate_log_likelihood nominate_geo_mean_probability  \
# ...
